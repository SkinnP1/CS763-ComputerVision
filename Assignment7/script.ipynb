# %%
import matplotlib.pyplot as plt

# %%
# Out:
# (78047, 30)
# (78047, 45)

# %%
d3loss = [1.455015778541565, 1.4282923936843872, 1.438159704208374, 1.4728132486343384, 1.464088797569275, 1.4269298315048218, 1.4655169248580933, 1.4440436363220215, 1.4580272436141968, 1.4863624572753906]
d2loss = [3.7324397563934326, 4.6366777420043945, 48.73081970214844, 4.750637531280518, 6.574243545532227, 3.532761812210083, 4.205659866333008, 4.275511264801025, 11.328807830810547, 4.494393348693848]

d3lossdropout = [1.575346399526127, 1.5751696977459015, 1.575123671234631, 1.5750984567110655, 1.5751955126152664, 1.5749652800012808, 1.5753096783747438, 1.575069640112705, 1.5748748279008709, 1.5751725994172643]
d2lossdropout = [0.6596938336481813, 0.6596812263863986, 0.65974606373271, 0.6596179899622182, 0.6596765236776383, 0.659503423972208, 0.6597146456358862, 0.6595669105404713, 0.659436285300333, 0.659631097512167]

d3batch = [1.185239698066086, 1.1852326940317623, 1.1852227883260757, 1.1852578084976946, 1.185222388095543, 1.1852301925909323, 1.1852353955878585, 1.1852183857902152, 1.1852407987000513, 1.1852685146644468]
d2batch =  [0.5137697313652664, 0.5137645283683402, 0.513748969406378, 0.5137656790311219, 0.5137745841604764, 0.5137802874455687, 0.5137748343045594, 0.5137713322873976, 0.5137688308465677, 0.5137673299820696]

d3layers3 = [2.034104844390369, 2.0335333151895494, 2.0338356893570695, 2.03386950883709, 2.033740834720799, 2.033546522797131, 2.0338845174820697, 2.0342851482453894, 2.0336799996798156, 2.033802670338115]
d2layers3 = [0.8364911188844775, 0.8365060775006403, 0.8364549980788935, 0.8362250156089908, 0.8362970571048924, 0.8360349561347336, 0.8364939204982069, 0.8362447769915471, 0.8366083364017675, 0.8363341284579918]

# %%
e = [i for i in range(1,11)]

# %%
plt.figure(figsize=(12,10))
plt.plot(e,d3loss,label="3D loss",color='r')
plt.plot(e,d2loss,label="2D loss",color='g')
plt.grid()
plt.title("Graph of training loss for 2 layers for Model 1")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig('2layers1.png')

# %%
plt.figure(figsize=(12,10))
plt.plot(e,d3lossdropout,label="3D loss",color='r')
plt.plot(e,d2lossdropout,label="2D loss",color='g')
plt.grid()
plt.title("Graph of training loss for 2 layers without using dropout for Model 2")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig('Dropout2.png')

# %%
plt.figure(figsize=(12,10))
plt.plot(e,d3batch,label="3D loss",color='r')
plt.plot(e,d2batch,label="2D loss",color='g')
plt.grid()
plt.title("Graph of training loss for 2 layers without using batch normalisation for Model 2")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig('BatchNormalisation2.png')

# %%
plt.figure(figsize=(12,10))
plt.plot(e,d3layers3,label="3D loss",color='r')
plt.plot(e,d2layers3,label="2D loss",color='g')
plt.grid()
plt.title("Graph of training loss for 3 layers for Model 2")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig('3Layers2.png')
